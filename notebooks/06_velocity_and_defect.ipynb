# %% [markdown]
# # Velocity and defect validation
#
# - Gabriel Wendell Celestino Rocha
# ---

# %% [markdown]
# Teaching notebook generated from tested `qhe` modules.

# %%
from qhe.dynamics import DynamicsConfig, analyze_chiral_dynamics

analysis = analyze_chiral_dynamics(DynamicsConfig())
print(f"> Defect: {analysis.weak_link}")
print(f"> Clean velocity: {analysis.clean.velocity_fit.velocity:.6f}")
print(f"> Defect velocity: {analysis.defect.velocity_fit.velocity:.6f}")
print(f"> Group velocity: {analysis.group_velocity:.6f}")
# Out:
# > Defect: WeakLinkDefect(side='left', position=11, factor=0.0)
# > Clean velocity: -1.536268
# > Defect velocity: -1.272623
# > Group velocity: -1.559444

# %%
print(f"> Clean mean edge probability: {analysis.clean.mean_edge_probability:.6f}")
print(f"> Defect mean edge probability: {analysis.defect.mean_edge_probability:.6f}")
print(f"> Defect relative velocity error: {analysis.defect_relative_velocity_error:.4f}")
# Out:
# > Clean mean edge probability: 0.910876
# > Defect mean edge probability: 0.903486
# > Defect relative velocity error: 0.1839

# %% [markdown]
# ---
