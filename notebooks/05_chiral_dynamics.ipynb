# %% [markdown]
# # Chiral dynamics
#
# - Gabriel Wendell Celestino Rocha
# ---

# %% [markdown]
# Teaching notebook generated from tested `qhe` modules.

# %%
from qhe.dynamics import DynamicsConfig, analyze_chiral_dynamics

analysis = analyze_chiral_dynamics(DynamicsConfig())
print(f"> Group velocity: {analysis.group_velocity:.6f}")
print(f"> Packet velocity: {analysis.clean.velocity_fit.velocity:.6f}")
print(f"> Relative error: {analysis.relative_velocity_error:.4f}")
# Out:
# > Group velocity: -1.559444
# > Packet velocity: -1.536268
# > Relative error: 0.0149

# %%
print(f"> Max norm deviation: {analysis.clean.norms.max_deviation:.3e}")
print(f"> Initial edge probability: {analysis.clean.initial_edge_probability:.6f}")
print(f"> Mean edge probability: {analysis.clean.mean_edge_probability:.6f}")
print(f"> Initial side-current indicator: {analysis.clean.side_current_initial:.6f}")
# Out:
# > Max norm deviation: 1.554e-15
# > Initial edge probability: 0.909715
# > Mean edge probability: 0.910876
# > Initial side-current indicator: -0.021710

# %% [markdown]
# ---
